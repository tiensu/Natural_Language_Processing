# %%
import sys
from google.colab import drive
drive.mount('/content/drive')
sys.path.append('/content/drive/Shareddrives/SnP_DATA/AI_Team/SuNT/AI_PRACTICE/text-generation/')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import string
import matplotlib.pyplot as plt
# %matplotlib inline
import re
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Concatenate, TimeDistributed
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from attention import AttentionLayer

# %% [markdown]
# ### Prepare dataset

# %%
# %cd /content/drive/Shareddrives/SnP_DATA/AI_Team/SuNT/AI_PRACTICE/text-generation/
# Out:
# /content/drive/Shareddrives/SnP_DATA/AI_Team/SuNT/AI_PRACTICE/text-generation

# %%
with open('poem_all.txt','r') as f:
  data = f.read()

# %%
data_list = []
data_list = [line for line in data.split('\n') if line != '' and line not in data_list]
data_list[:10]
# Out:
# ['Trăm năm trong cõi người ta',
#  'Chữ tài chữ mệnh khéo là ghét nhau',
#  'Trải qua một cuộc bể dâu',
#  'Những điều trông thấy mà đau đớn lòng',
#  'Lạ gì bỉ sắc tư phong',
#  'Trời xanh quen thói má hồng đánh ghen',
#  'Cảo thơm lần giở trước đèn',
#  'Phong tình có lục còn truyền sử xanh',
#  'Rằng năm Gia Tĩnh triều Minh',
#  'Bốn phương phẳng lặng hai kinh vững vàng']

# %%
data_list = [x.lower() for x in data_list]
data_list[:10]
# Out:
# ['trăm năm trong cõi người ta',
#  'chữ tài chữ mệnh khéo là ghét nhau',
#  'trải qua một cuộc bể dâu',
#  'những điều trông thấy mà đau đớn lòng',
#  'lạ gì bỉ sắc tư phong',
#  'trời xanh quen thói má hồng đánh ghen',
#  'cảo thơm lần giở trước đèn',
#  'phong tình có lục còn truyền sử xanh',
#  'rằng năm gia tĩnh triều minh',
#  'bốn phương phẳng lặng hai kinh vững vàng']

# %%
remove_punc = str.maketrans('', '', string.punctuation)
removed_punc_text = []
for sent in data_list:
  sentance = [w.translate(remove_punc) for w in sent.split(' ')]
  removed_punc_text.append(' '.join(sentance))
tk_text_ = removed_punc_text
tk_text_[:10]
# Out:
# ['trăm năm trong cõi người ta',
#  'chữ tài chữ mệnh khéo là ghét nhau',
#  'trải qua một cuộc bể dâu',
#  'những điều trông thấy mà đau đớn lòng',
#  'lạ gì bỉ sắc tư phong',
#  'trời xanh quen thói má hồng đánh ghen',
#  'cảo thơm lần giở trước đèn',
#  'phong tình có lục còn truyền sử xanh',
#  'rằng năm gia tĩnh triều minh',
#  'bốn phương phẳng lặng hai kinh vững vàng']

# %%
remove_digits = str.maketrans('', '', string.digits)
removed_digits_text = []
for sent in tk_text_:
    sentance = [w.translate(remove_digits) for w in sent.split(' ')]
    removed_digits_text.append(' '.join(sentance))
tk_text_ = removed_digits_text
tk_text_[:10]
# Out:
# ['trăm năm trong cõi người ta',
#  'chữ tài chữ mệnh khéo là ghét nhau',
#  'trải qua một cuộc bể dâu',
#  'những điều trông thấy mà đau đớn lòng',
#  'lạ gì bỉ sắc tư phong',
#  'trời xanh quen thói má hồng đánh ghen',
#  'cảo thơm lần giở trước đèn',
#  'phong tình có lục còn truyền sử xanh',
#  'rằng năm gia tĩnh triều minh',
#  'bốn phương phẳng lặng hai kinh vững vàng']

# %%
# removing the starting and ending whitespaces
tk_text_ = [st.strip() for st in tk_text_]
tk_text_[:10]
# Out:
# ['trăm năm trong cõi người ta',
#  'chữ tài chữ mệnh khéo là ghét nhau',
#  'trải qua một cuộc bể dâu',
#  'những điều trông thấy mà đau đớn lòng',
#  'lạ gì bỉ sắc tư phong',
#  'trời xanh quen thói má hồng đánh ghen',
#  'cảo thơm lần giở trước đèn',
#  'phong tình có lục còn truyền sử xanh',
#  'rằng năm gia tĩnh triều minh',
#  'bốn phương phẳng lặng hai kinh vững vàng']

# %%
# remove … and – character
tk_text_ = [st.replace('…', '') for st in tk_text_]
tk_text_ = [st.replace('– ', '') for st in tk_text_]

# %%
# check to see if there is 2 sentences are same line
for ins in tk_text_:
    if len(ins.split()) > 12:
      print(ins)

# %%
# create pair of input/output sequence
input_sentences, target_sentences = [], []
for index, seq_txt in enumerate(tk_text_):
    if index%2 == 0:
        input_sentences.append(seq_txt)
    else:
        target_sentences.append(seq_txt)

# %%
len(input_sentences), len(target_sentences)
# Out:
# (3245, 3245)

# %%
# add start and end token to target sequences
target_sentences = ['start '+ ts + ' end' for ts in target_sentences]

# %%
# prepare the tokenizer on the input sentence
input_tokenizer = Tokenizer()
input_tokenizer.fit_on_texts(input_sentences)
# determine the vocabulary size
input_vocab_size = len(input_tokenizer.word_index) + 1
print('Input Vocabulary Size: %d' % input_vocab_size)
# create word2index dictionary
input_word2index = input_tokenizer.word_index
# create index2word dictionary
input_index2word = input_tokenizer.index_word
# Out:
# Input Vocabulary Size: 2551

# %%
# perform tokenize on input setences
input_seq = input_tokenizer.texts_to_sequences(input_sentences)
max_len_input_seq = max([len(seq) for seq in input_seq])
input_seq = pad_sequences(input_seq, maxlen=max_len_input_seq, padding='pre')
input_seq[:10]
# Out:
# array([[   0,    0,    0,    0,  204,   45,   11,  621,   10,   46],
#        [   0,    0,    0,    0,  539,   77,    3,  222,  261,  366],
#        [   0,    0,    0,    0,  233,  282, 1298,  234,  401,  191],
#        [   0,    0,    0,    0, 1677,  540,  127,  541,   96,  402],
#        [   0,    0,    0,    0,    6,   45,  205, 1299,  813,  247],
#        [   0,    0,    0,    0,   22,   52, 1300,  704,  433,  192],
#        [   0,    0,    0,    0,    3,  814,   57,  953, 1678,    9],
#        [   0,    0,    0,    0,  136,    9,   51,  954, 1087,  705],
#        [   0,    0,    0,    0,  107,  815,  344,  816,  542,  452],
#        [   0,    0,    0,    0,  543,  345,  403,  706,  955,  404]],
#       dtype=int32)

# %%
# prepare the tokenizer on the target sentence
target_tokenizer = Tokenizer()
target_tokenizer.fit_on_texts(target_sentences)
# determine the vocabulary size
target_vocab_size = len(target_tokenizer.word_index) + 1
print('Target Vocabulary Size: %d' % target_vocab_size)
# create word2index dictionary
target_word2index = target_tokenizer.word_index
# create index2word dictionary
target_index2word = target_tokenizer.index_word
# Out:
# Target Vocabulary Size: 2588

# %%
# perform tokenize on target setences
target_seq = target_tokenizer.texts_to_sequences(target_sentences)
max_len_target_seq = max([len(seq) for seq in target_seq])
target_seq = pad_sequences(target_seq, maxlen=max_len_target_seq, padding='pre')
target_seq[:10]
# Out:
# array([[   0,    0,    0,    0,    1,  148,  296,  148,  484,  439,   11,
#         1403,   34,    2],
#        [   0,    0,    0,    0,    1,   63,  155,  122,   72,   24,   73,
#          627,    6,    2],
#        [   0,    0,    0,    0,    1,   52,  108,  361,  872,  297,   69,
#          628,  519,    2],
#        [   0,    0,    0,    0,    1,  243,    5,   13,  873,   14,  990,
#         1773,  108,    2],
#        [   0,    0,    0,    0,    1,  167,  404, 1774,  281,   46,  312,
#          991,   56,    2],
#        [   0,    0,    0,    0,    1,  520,  768,  208,   12,  337,  337,
#         1775,  992,    2],
#        [   0,    0,    0,    0,    1,  130,  282,   11,  148,  629,  230,
#         1404,  520,    2],
#        [   0,    0,    0,    0,    1,  874,  440,   11,  338,    3,   11,
#          874,  362,    2],
#        [   0,    0,    0,    0,    1,    4,    8,    4,  566,  197,  521,
#          696,  197,    2],
#        [   0,    0,    0,    0,    1,  769,  104,  168, 1776,  567, 1405,
#          485, 1406,    2]], dtype=int32)

# %%
# create encoder/decoder input/output
encoder_input_data = np.zeros((len(input_sentences), max_len_input_seq), dtype='float32')
decoder_input_data = np.zeros((len(target_sentences), max_len_target_seq),dtype='float32')
decoder_target_data = np.zeros((len(target_sentences), max_len_target_seq, target_vocab_size), dtype='float32')

# init encoder/decoder input/output
for i, (input_text, target_text) in enumerate(zip(input_sentences, target_sentences)):
    for t, word in enumerate(input_text.split()):
        encoder_input_data[i, t] = input_word2index[word]
    for t, word in enumerate(target_text.split()):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t] = target_word2index[word]
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_word2index[word]] = 1.

# %% [markdown]
# ### Define model

# %%
from tensorflow.keras import backend as K 
K.clear_session() 
latent_dim = 50

# %%
# Encoder 
encoder_inputs = Input(shape=(max_len_input_seq,)) 
enc_emb = Embedding(input_vocab_size, latent_dim, trainable=True)(encoder_inputs) 

#LSTM 1 
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb) 

#LSTM 2 
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1) 

#LSTM 3 
encoder_lstm3 = LSTM(latent_dim, return_state=True, return_sequences=True) 
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# %%
# Set up the decoder. 
decoder_inputs = Input(shape=(None,)) 
dec_emb_layer = Embedding(target_vocab_size, latent_dim, trainable=True) 
dec_emb = dec_emb_layer(decoder_inputs) 

#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True) 
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

# %%
#Attention Layer
attn_layer = AttentionLayer(name='attention_layer') 
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# %%
# Concat attention output and decoder LSTM output 
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# %%
#Dense layer
decoder_dense = TimeDistributed(Dense(target_vocab_size, activation='softmax')) 
decoder_outputs = decoder_dense(decoder_concat_input)

# %%
# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs) 
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 10, 50)       127550      input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 10, 50), (No 20200       embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 10, 50), (No 20200       lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 50)     129400      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 10, 50), (No 20200       lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 50), ( 20200       embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 50), ( 5050        lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 100)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 2588)   261388      concat_layer[0][0]
# ==================================================================================================
# Total params: 604,188
# Trainable params: 604,188
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# compile model
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

# %%
# plot model
plot_model(model, to_file='output/model_arch.png', show_shapes=True)

# %%
history = model.fit(
    x=[encoder_input_data, decoder_input_data],
    y=decoder_target_data,
    batch_size=64,
    epochs=1000)
# Out:
# Epoch 1/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 3.3023 - acc: 0.0850
# Epoch 2/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 3.2820 - acc: 0.0857
# Epoch 3/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 3.2624 - acc: 0.0858
# Epoch 4/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 3.2447 - acc: 0.0866
# Epoch 5/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 3.2256 - acc: 0.0871
# Epoch 6/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 3.2063 - acc: 0.0877
# Epoch 7/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 3.1872 - acc: 0.0886
# Epoch 8/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 3.1684 - acc: 0.0896
# Epoch 9/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 3.1490 - acc: 0.0905
# Epoch 10/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 3.1305 - acc: 0.0908
# Epoch 11/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 3.1115 - acc: 0.0921
# Epoch 12/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 3.0924 - acc: 0.0933
# Epoch 13/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 3.0754 - acc: 0.0937
# Epoch 14/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 3.0581 - acc: 0.0956
# Epoch 15/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 3.0391 - acc: 0.0957
# Epoch 16/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 3.0230 - acc: 0.0968
# Epoch 17/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 3.0028 - acc: 0.0970
# Epoch 18/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 2.9882 - acc: 0.0978
# Epoch 19/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 2.9690 - acc: 0.0985
# Epoch 20/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 2.9542 - acc: 0.1003
# Epoch 21/1000
# 51/51 [==============================] - 3s 52ms/step - loss: 2.9367 - acc: 0.1016
# Epoch 22/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 2.9196 - acc: 0.1030
# Epoch 23/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 2.9014 - acc: 0.1038
# Epoch 24/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 2.8821 - acc: 0.1059
# Epoch 25/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 2.8696 - acc: 0.1056
# Epoch 26/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 2.8476 - acc: 0.1074
# Epoch 27/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 2.8327 - acc: 0.1096
# Epoch 28/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 2.8161 - acc: 0.1101
# Epoch 29/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 2.7984 - acc: 0.1130
# Epoch 30/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 2.7833 - acc: 0.1134
# Epoch 31/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 2.7656 - acc: 0.1156
# Epoch 32/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 2.7516 - acc: 0.1168
# Epoch 33/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 2.7338 - acc: 0.1180
# Epoch 34/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 2.7159 - acc: 0.1185
# Epoch 35/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 2.7027 - acc: 0.1205
# Epoch 36/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 2.6882 - acc: 0.1217
# Epoch 37/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 2.6720 - acc: 0.1237
# Epoch 38/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 2.6557 - acc: 0.1253
# Epoch 39/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 2.6393 - acc: 0.1278
# Epoch 40/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 2.6217 - acc: 0.1289
# Epoch 41/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 2.6074 - acc: 0.1304
# Epoch 42/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 2.5897 - acc: 0.1329
# Epoch 43/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 2.5745 - acc: 0.1350
# Epoch 44/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 2.5583 - acc: 0.1366
# Epoch 45/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 2.5450 - acc: 0.1379
# Epoch 46/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 2.5304 - acc: 0.1389
# Epoch 47/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 2.5149 - acc: 0.1419
# Epoch 48/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 2.4963 - acc: 0.1429
# Epoch 49/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 2.4844 - acc: 0.1444
# Epoch 50/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 2.4712 - acc: 0.1475
# Epoch 51/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 2.4509 - acc: 0.1493
# Epoch 52/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 2.4396 - acc: 0.1511
# Epoch 53/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 2.4225 - acc: 0.1516
# Epoch 54/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 2.4075 - acc: 0.1541
# Epoch 55/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 2.3920 - acc: 0.1565
# Epoch 56/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 2.3816 - acc: 0.1589
# Epoch 57/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 2.3616 - acc: 0.1617
# Epoch 58/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 2.3484 - acc: 0.1631
# Epoch 59/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 2.3299 - acc: 0.1665
# Epoch 60/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 2.3165 - acc: 0.1680
# Epoch 61/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 2.2997 - acc: 0.1707
# Epoch 62/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 2.2866 - acc: 0.1737
# Epoch 63/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 2.2694 - acc: 0.1746
# Epoch 64/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 2.2569 - acc: 0.1755
# Epoch 65/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 2.2425 - acc: 0.1794
# Epoch 66/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 2.2267 - acc: 0.1820
# Epoch 67/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 2.2108 - acc: 0.1838
# Epoch 68/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 2.1968 - acc: 0.1870
# Epoch 69/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 2.1816 - acc: 0.1897
# Epoch 70/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 2.1691 - acc: 0.1915
# Epoch 71/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 2.1509 - acc: 0.1947
# Epoch 72/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 2.1390 - acc: 0.1948
# Epoch 73/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 2.1210 - acc: 0.1991
# Epoch 74/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 2.1055 - acc: 0.2017
# Epoch 75/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 2.0955 - acc: 0.2029
# Epoch 76/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 2.0786 - acc: 0.2068
# Epoch 77/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 2.0635 - acc: 0.2084
# Epoch 78/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 2.0511 - acc: 0.2108
# Epoch 79/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 2.0346 - acc: 0.2139
# Epoch 80/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 2.0238 - acc: 0.2160
# Epoch 81/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 2.0052 - acc: 0.2200
# Epoch 82/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 1.9937 - acc: 0.2212
# Epoch 83/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 1.9772 - acc: 0.2245
# Epoch 84/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 1.9636 - acc: 0.2262
# Epoch 85/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 1.9485 - acc: 0.2290
# Epoch 86/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 1.9375 - acc: 0.2323
# Epoch 87/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 1.9229 - acc: 0.2335
# Epoch 88/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 1.9070 - acc: 0.2364
# Epoch 89/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 1.8933 - acc: 0.2384
# Epoch 90/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.8820 - acc: 0.2423
# Epoch 91/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 1.8676 - acc: 0.2439
# Epoch 92/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 1.8515 - acc: 0.2464
# Epoch 93/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 1.8389 - acc: 0.2490
# Epoch 94/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 1.8255 - acc: 0.2517
# Epoch 95/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 1.8105 - acc: 0.2545
# Epoch 96/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 1.7956 - acc: 0.2571
# Epoch 97/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 1.7863 - acc: 0.2593
# Epoch 98/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 1.7715 - acc: 0.2619
# Epoch 99/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 1.7585 - acc: 0.2643
# Epoch 100/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 1.7413 - acc: 0.2673
# Epoch 101/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.7312 - acc: 0.2686
# Epoch 102/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.7154 - acc: 0.2728
# Epoch 103/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 1.7069 - acc: 0.2746
# Epoch 104/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 1.6932 - acc: 0.2784
# Epoch 105/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 1.6767 - acc: 0.2801
# Epoch 106/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 1.6657 - acc: 0.2819
# Epoch 107/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 1.6552 - acc: 0.2850
# Epoch 108/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 1.6384 - acc: 0.2885
# Epoch 109/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 1.6257 - acc: 0.2906
# Epoch 110/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 1.6162 - acc: 0.2912
# Epoch 111/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 1.6004 - acc: 0.2962
# Epoch 112/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.5887 - acc: 0.2973
# Epoch 113/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 1.5829 - acc: 0.2992
# Epoch 114/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 1.5676 - acc: 0.3007
# Epoch 115/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 1.5533 - acc: 0.3052
# Epoch 116/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 1.5427 - acc: 0.3068
# Epoch 117/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 1.5277 - acc: 0.3094
# Epoch 118/1000
# 51/51 [==============================] - 3s 52ms/step - loss: 1.5200 - acc: 0.3114
# Epoch 119/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 1.5076 - acc: 0.3139
# Epoch 120/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.4950 - acc: 0.3149
# Epoch 121/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.4815 - acc: 0.3187
# Epoch 122/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 1.4715 - acc: 0.3207
# Epoch 123/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.4579 - acc: 0.3229
# Epoch 124/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 1.4483 - acc: 0.3260
# Epoch 125/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 1.4347 - acc: 0.3273
# Epoch 126/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 1.4286 - acc: 0.3287
# Epoch 127/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.4131 - acc: 0.3327
# Epoch 128/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 1.4053 - acc: 0.3354
# Epoch 129/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 1.3922 - acc: 0.3361
# Epoch 130/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 1.3812 - acc: 0.3388
# Epoch 131/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 1.3680 - acc: 0.3412
# Epoch 132/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 1.3578 - acc: 0.3442
# Epoch 133/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 1.3477 - acc: 0.3453
# Epoch 134/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 1.3342 - acc: 0.3473
# Epoch 135/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 1.3264 - acc: 0.3495
# Epoch 136/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 1.3186 - acc: 0.3508
# Epoch 137/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 1.3060 - acc: 0.3535
# Epoch 138/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 1.2991 - acc: 0.3547
# Epoch 139/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 1.2836 - acc: 0.3587
# Epoch 140/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.2772 - acc: 0.3599
# Epoch 141/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 1.2639 - acc: 0.3626
# Epoch 142/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 1.2564 - acc: 0.3614
# Epoch 143/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 1.2459 - acc: 0.3655
# Epoch 144/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.2331 - acc: 0.3687
# Epoch 145/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 1.2287 - acc: 0.3699
# Epoch 146/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.2178 - acc: 0.3712
# Epoch 147/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 1.2082 - acc: 0.3732
# Epoch 148/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 1.1956 - acc: 0.3753
# Epoch 149/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 1.1876 - acc: 0.3769
# Epoch 150/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 1.1759 - acc: 0.3795
# Epoch 151/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 1.1641 - acc: 0.3810
# Epoch 152/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.1635 - acc: 0.3813
# Epoch 153/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 1.1528 - acc: 0.3847
# Epoch 154/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 1.1414 - acc: 0.3857
# Epoch 155/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 1.1267 - acc: 0.3906
# Epoch 156/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 1.1278 - acc: 0.3874
# Epoch 157/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 1.1144 - acc: 0.3916
# Epoch 158/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 1.1064 - acc: 0.3941
# Epoch 159/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 1.0975 - acc: 0.3961
# Epoch 160/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 1.0893 - acc: 0.3968
# Epoch 161/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 1.0791 - acc: 0.3987
# Epoch 162/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.0743 - acc: 0.3990
# Epoch 163/1000
# 51/51 [==============================] - 3s 52ms/step - loss: 1.0646 - acc: 0.4020
# Epoch 164/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 1.0564 - acc: 0.4044
# Epoch 165/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 1.0462 - acc: 0.4057
# Epoch 166/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 1.0383 - acc: 0.4077
# Epoch 167/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 1.0297 - acc: 0.4090
# Epoch 168/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 1.0247 - acc: 0.4111
# Epoch 169/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 1.0168 - acc: 0.4116
# Epoch 170/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 1.0045 - acc: 0.4154
# Epoch 171/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.9989 - acc: 0.4158
# Epoch 172/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.9927 - acc: 0.4170
# Epoch 173/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.9849 - acc: 0.4193
# Epoch 174/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.9754 - acc: 0.4207
# Epoch 175/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.9719 - acc: 0.4217
# Epoch 176/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.9593 - acc: 0.4235
# Epoch 177/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.9526 - acc: 0.4254
# Epoch 178/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.9460 - acc: 0.4258
# Epoch 179/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.9376 - acc: 0.4287
# Epoch 180/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.9286 - acc: 0.4293
# Epoch 181/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.9229 - acc: 0.4318
# Epoch 182/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.9155 - acc: 0.4338
# Epoch 183/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.9082 - acc: 0.4340
# Epoch 184/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.9049 - acc: 0.4353
# Epoch 185/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.8941 - acc: 0.4371
# Epoch 186/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.8868 - acc: 0.4389
# Epoch 187/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.8839 - acc: 0.4405
# Epoch 188/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.8765 - acc: 0.4416
# Epoch 189/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.8655 - acc: 0.4443
# Epoch 190/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.8630 - acc: 0.4436
# Epoch 191/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.8535 - acc: 0.4459
# Epoch 192/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.8468 - acc: 0.4462
# Epoch 193/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.8439 - acc: 0.4488
# Epoch 194/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.8322 - acc: 0.4497
# Epoch 195/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.8293 - acc: 0.4509
# Epoch 196/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.8265 - acc: 0.4513
# Epoch 197/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.8130 - acc: 0.4536
# Epoch 198/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.8048 - acc: 0.4562
# Epoch 199/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.8054 - acc: 0.4548
# Epoch 200/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.7966 - acc: 0.4571
# Epoch 201/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.7882 - acc: 0.4603
# Epoch 202/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.7811 - acc: 0.4606
# Epoch 203/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.7767 - acc: 0.4617
# Epoch 204/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.7711 - acc: 0.4630
# Epoch 205/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.7632 - acc: 0.4647
# Epoch 206/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.7606 - acc: 0.4651
# Epoch 207/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.7536 - acc: 0.4659
# Epoch 208/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.7488 - acc: 0.4679
# Epoch 209/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.7440 - acc: 0.4683
# Epoch 210/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.7331 - acc: 0.4709
# Epoch 211/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.7322 - acc: 0.4711
# Epoch 212/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.7239 - acc: 0.4727
# Epoch 213/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.7185 - acc: 0.4745
# Epoch 214/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.7112 - acc: 0.4752
# Epoch 215/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.7075 - acc: 0.4764
# Epoch 216/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.6991 - acc: 0.4791
# Epoch 217/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.7003 - acc: 0.4778
# Epoch 218/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.6892 - acc: 0.4807
# Epoch 219/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.6874 - acc: 0.4801
# Epoch 220/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.6818 - acc: 0.4827
# Epoch 221/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.6698 - acc: 0.4856
# Epoch 222/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.6703 - acc: 0.4844
# Epoch 223/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.6673 - acc: 0.4854
# Epoch 224/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.6549 - acc: 0.4884
# Epoch 225/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.6547 - acc: 0.4888
# Epoch 226/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.6453 - acc: 0.4903
# Epoch 227/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.6431 - acc: 0.4899
# Epoch 228/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.6355 - acc: 0.4925
# Epoch 229/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.6337 - acc: 0.4927
# Epoch 230/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.6264 - acc: 0.4934
# Epoch 231/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.6247 - acc: 0.4946
# Epoch 232/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.6161 - acc: 0.4978
# Epoch 233/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.6134 - acc: 0.4970
# Epoch 234/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.6073 - acc: 0.4981
# Epoch 235/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.6035 - acc: 0.4994
# Epoch 236/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.5981 - acc: 0.5002
# Epoch 237/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.5915 - acc: 0.5019
# Epoch 238/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.5917 - acc: 0.5017
# Epoch 239/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.5793 - acc: 0.5054
# Epoch 240/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.5804 - acc: 0.5044
# Epoch 241/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.5752 - acc: 0.5066
# Epoch 242/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.5693 - acc: 0.5068
# Epoch 243/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.5650 - acc: 0.5079
# Epoch 244/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.5633 - acc: 0.5078
# Epoch 245/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.5527 - acc: 0.5106
# Epoch 246/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.5559 - acc: 0.5096
# Epoch 247/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.5494 - acc: 0.5097
# Epoch 248/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.5418 - acc: 0.5127
# Epoch 249/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.5396 - acc: 0.5126
# Epoch 250/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.5327 - acc: 0.5146
# Epoch 251/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.5315 - acc: 0.5143
# Epoch 252/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.5277 - acc: 0.5165
# Epoch 253/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.5225 - acc: 0.5162
# Epoch 254/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.5182 - acc: 0.5171
# Epoch 255/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.5121 - acc: 0.5194
# Epoch 256/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.5106 - acc: 0.5194
# Epoch 257/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.5052 - acc: 0.5193
# Epoch 258/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.5023 - acc: 0.5208
# Epoch 259/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.4960 - acc: 0.5212
# Epoch 260/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.4915 - acc: 0.5226
# Epoch 261/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.4913 - acc: 0.5227
# Epoch 262/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.4860 - acc: 0.5235
# Epoch 263/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.4853 - acc: 0.5240
# Epoch 264/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.4786 - acc: 0.5264
# Epoch 265/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.4759 - acc: 0.5255
# Epoch 266/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 0.4679 - acc: 0.5273
# Epoch 267/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 0.4692 - acc: 0.5260
# Epoch 268/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 0.4629 - acc: 0.5278
# Epoch 269/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.4583 - acc: 0.5297
# Epoch 270/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 0.4565 - acc: 0.5299
# Epoch 271/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.4545 - acc: 0.5309
# Epoch 272/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 0.4468 - acc: 0.5321
# Epoch 273/1000
# 51/51 [==============================] - 3s 51ms/step - loss: 0.4469 - acc: 0.5322
# Epoch 274/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.4420 - acc: 0.5319
# Epoch 275/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.4373 - acc: 0.5338
# Epoch 276/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.4330 - acc: 0.5338
# Epoch 277/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.4336 - acc: 0.5340
# Epoch 278/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.4304 - acc: 0.5336
# Epoch 279/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.4263 - acc: 0.5351
# Epoch 280/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.4198 - acc: 0.5376
# Epoch 281/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.4187 - acc: 0.5371
# Epoch 282/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.4132 - acc: 0.5382
# Epoch 283/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.4112 - acc: 0.5389
# Epoch 284/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.4107 - acc: 0.5381
# Epoch 285/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.4051 - acc: 0.5400
# Epoch 286/1000
# 51/51 [==============================] - 3s 51ms/step - loss: 0.4029 - acc: 0.5396
# Epoch 287/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.3944 - acc: 0.5427
# Epoch 288/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.3971 - acc: 0.5418
# Epoch 289/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.3964 - acc: 0.5423
# Epoch 290/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.3933 - acc: 0.5427
# Epoch 291/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.3852 - acc: 0.5438
# Epoch 292/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.3823 - acc: 0.5450
# Epoch 293/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.3785 - acc: 0.5465
# Epoch 294/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.3776 - acc: 0.5466
# Epoch 295/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.3742 - acc: 0.5472
# Epoch 296/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.3727 - acc: 0.5468
# Epoch 297/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.3672 - acc: 0.5474
# Epoch 298/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 0.3659 - acc: 0.5488
# Epoch 299/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.3646 - acc: 0.5486
# Epoch 300/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.3560 - acc: 0.5511
# Epoch 301/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.3569 - acc: 0.5507
# Epoch 302/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.3542 - acc: 0.5509
# Epoch 303/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 0.3529 - acc: 0.5519
# Epoch 304/1000
# 51/51 [==============================] - 3s 52ms/step - loss: 0.3466 - acc: 0.5525
# Epoch 305/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 0.3450 - acc: 0.5530
# Epoch 306/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.3430 - acc: 0.5525
# Epoch 307/1000
# 51/51 [==============================] - 3s 52ms/step - loss: 0.3405 - acc: 0.5539
# Epoch 308/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 0.3387 - acc: 0.5539
# Epoch 309/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.3351 - acc: 0.5553
# Epoch 310/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.3322 - acc: 0.5546
# Epoch 311/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.3316 - acc: 0.5551
# Epoch 312/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.3239 - acc: 0.5576
# Epoch 313/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.3202 - acc: 0.5582
# Epoch 314/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.3221 - acc: 0.5584
# Epoch 315/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.3167 - acc: 0.5587
# Epoch 316/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.3175 - acc: 0.5582
# Epoch 317/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.3123 - acc: 0.5596
# Epoch 318/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.3116 - acc: 0.5595
# Epoch 319/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.3085 - acc: 0.5606
# Epoch 320/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.3059 - acc: 0.5605
# Epoch 321/1000
# 51/51 [==============================] - 3s 52ms/step - loss: 0.3050 - acc: 0.5610
# Epoch 322/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.2990 - acc: 0.5620
# Epoch 323/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.2953 - acc: 0.5646
# Epoch 324/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.2971 - acc: 0.5628
# Epoch 325/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 0.2918 - acc: 0.5642
# Epoch 326/1000
# 51/51 [==============================] - 3s 51ms/step - loss: 0.2929 - acc: 0.5636
# Epoch 327/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 0.2918 - acc: 0.5632
# Epoch 328/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.2854 - acc: 0.5654
# Epoch 329/1000
# 51/51 [==============================] - 3s 53ms/step - loss: 0.2821 - acc: 0.5662
# Epoch 330/1000
# 51/51 [==============================] - 3s 54ms/step - loss: 0.2840 - acc: 0.5656
# Epoch 331/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.2798 - acc: 0.5667
# Epoch 332/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.2780 - acc: 0.5667
# Epoch 333/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.2743 - acc: 0.5683
# Epoch 334/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.2696 - acc: 0.5693
# Epoch 335/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.2716 - acc: 0.5683
# Epoch 336/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.2723 - acc: 0.5682
# Epoch 337/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.2649 - acc: 0.5703
# Epoch 338/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.2635 - acc: 0.5702
# Epoch 339/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.2642 - acc: 0.5696
# Epoch 340/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.2580 - acc: 0.5708
# Epoch 341/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.2586 - acc: 0.5710
# Epoch 342/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.2574 - acc: 0.5705
# Epoch 343/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.2484 - acc: 0.5739
# Epoch 344/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.2522 - acc: 0.5723
# Epoch 345/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.2510 - acc: 0.5724
# Epoch 346/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.2447 - acc: 0.5734
# Epoch 347/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.2464 - acc: 0.5730
# Epoch 348/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.2428 - acc: 0.5738
# Epoch 349/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.2433 - acc: 0.5741
# Epoch 350/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.2385 - acc: 0.5746
# Epoch 351/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.2362 - acc: 0.5753
# Epoch 352/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.2368 - acc: 0.5748
# Epoch 353/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.2314 - acc: 0.5770
# Epoch 354/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.2315 - acc: 0.5753
# Epoch 355/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.2299 - acc: 0.5762
# Epoch 356/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.2271 - acc: 0.5772
# Epoch 357/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.2248 - acc: 0.5778
# Epoch 358/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.2271 - acc: 0.5772
# Epoch 359/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.2216 - acc: 0.5783
# Epoch 360/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.2223 - acc: 0.5777
# Epoch 361/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.2164 - acc: 0.5790
# Epoch 362/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.2171 - acc: 0.5788
# Epoch 363/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.2180 - acc: 0.5786
# Epoch 364/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.2105 - acc: 0.5806
# Epoch 365/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.2111 - acc: 0.5805
# Epoch 366/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.2096 - acc: 0.5804
# Epoch 367/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.2115 - acc: 0.5804
# Epoch 368/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.2025 - acc: 0.5823
# Epoch 369/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.2072 - acc: 0.5805
# Epoch 370/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.2029 - acc: 0.5816
# Epoch 371/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.2044 - acc: 0.5816
# Epoch 372/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.2032 - acc: 0.5812
# Epoch 373/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.1967 - acc: 0.5831
# Epoch 374/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.1941 - acc: 0.5834
# Epoch 375/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.1953 - acc: 0.5832
# Epoch 376/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.1946 - acc: 0.5837
# Epoch 377/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.1939 - acc: 0.5832
# Epoch 378/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.1967 - acc: 0.5832
# Epoch 379/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.1870 - acc: 0.5853
# Epoch 380/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.1872 - acc: 0.5853
# Epoch 381/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.1888 - acc: 0.5834
# Epoch 382/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.1817 - acc: 0.5866
# Epoch 383/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.1850 - acc: 0.5853
# Epoch 384/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.1833 - acc: 0.5848
# Epoch 385/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.1810 - acc: 0.5860
# Epoch 386/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.1783 - acc: 0.5864
# Epoch 387/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.1776 - acc: 0.5864
# Epoch 388/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.1728 - acc: 0.5871
# Epoch 389/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.1772 - acc: 0.5865
# Epoch 390/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.1746 - acc: 0.5872
# Epoch 391/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.1717 - acc: 0.5866
# Epoch 392/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.1673 - acc: 0.5881
# Epoch 393/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.1705 - acc: 0.5872
# Epoch 394/1000
# 51/51 [==============================] - 3s 56ms/step - loss: 0.1695 - acc: 0.5873
# Epoch 395/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.1638 - acc: 0.5885
# Epoch 396/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.1670 - acc: 0.5881
# Epoch 397/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.1609 - acc: 0.5898
# Epoch 398/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.1611 - acc: 0.5889
# Epoch 399/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.1592 - acc: 0.5893
# Epoch 400/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.1592 - acc: 0.5890
# Epoch 401/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.1645 - acc: 0.5881
# Epoch 402/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.1540 - acc: 0.5903
# Epoch 403/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.1579 - acc: 0.5888
# Epoch 404/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.1543 - acc: 0.5901
# Epoch 405/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.1509 - acc: 0.5907
# Epoch 406/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.1533 - acc: 0.5901
# Epoch 407/1000
# 51/51 [==============================] - 3s 55ms/step - loss: 0.1479 - acc: 0.5916
# Epoch 408/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.1488 - acc: 0.5913
# Epoch 409/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.1475 - acc: 0.5913
# Epoch 410/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.1498 - acc: 0.5905
# Epoch 411/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.1499 - acc: 0.5910
# Epoch 412/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.1420 - acc: 0.5926
# Epoch 413/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.1438 - acc: 0.5922
# Epoch 414/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.1427 - acc: 0.5922
# Epoch 415/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.1382 - acc: 0.5933
# Epoch 416/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.1411 - acc: 0.5916
# Epoch 417/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.1375 - acc: 0.5933
# Epoch 418/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.1365 - acc: 0.5937
# Epoch 419/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.1379 - acc: 0.5929
# Epoch 420/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.1346 - acc: 0.5932
# Epoch 421/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.1349 - acc: 0.5931
# Epoch 422/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.1337 - acc: 0.5940
# Epoch 423/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.1308 - acc: 0.5939
# Epoch 424/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.1316 - acc: 0.5943
# Epoch 425/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.1339 - acc: 0.5938
# Epoch 426/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.1265 - acc: 0.5947
# Epoch 427/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.1299 - acc: 0.5947
# Epoch 428/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.1259 - acc: 0.5952
# Epoch 429/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.1279 - acc: 0.5942
# Epoch 430/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.1244 - acc: 0.5955
# Epoch 431/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.1244 - acc: 0.5950
# Epoch 432/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.1241 - acc: 0.5956
# Epoch 433/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.1236 - acc: 0.5950
# Epoch 434/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.1232 - acc: 0.5949
# Epoch 435/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.1208 - acc: 0.5959
# Epoch 436/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.1187 - acc: 0.5965
# Epoch 437/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.1204 - acc: 0.5958
# Epoch 438/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.1183 - acc: 0.5963
# Epoch 439/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.1148 - acc: 0.5966
# Epoch 440/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.1149 - acc: 0.5966
# Epoch 441/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.1135 - acc: 0.5966
# Epoch 442/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.1146 - acc: 0.5968
# Epoch 443/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.1143 - acc: 0.5968
# Epoch 444/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.1096 - acc: 0.5973
# Epoch 445/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.1126 - acc: 0.5963
# Epoch 446/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.1084 - acc: 0.5976
# Epoch 447/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.1131 - acc: 0.5965
# Epoch 448/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.1103 - acc: 0.5969
# Epoch 449/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.1072 - acc: 0.5979
# Epoch 450/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.1063 - acc: 0.5981
# Epoch 451/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.1067 - acc: 0.5973
# Epoch 452/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.1048 - acc: 0.5983
# Epoch 453/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.1052 - acc: 0.5985
# Epoch 454/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.1004 - acc: 0.5988
# Epoch 455/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.1035 - acc: 0.5986
# Epoch 456/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0994 - acc: 0.5992
# Epoch 457/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.1062 - acc: 0.5978
# Epoch 458/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.1018 - acc: 0.5980
# Epoch 459/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0958 - acc: 0.6001
# Epoch 460/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0995 - acc: 0.5988
# Epoch 461/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.1003 - acc: 0.5983
# Epoch 462/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.0986 - acc: 0.5983
# Epoch 463/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.0964 - acc: 0.5991
# Epoch 464/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.0945 - acc: 0.6004
# Epoch 465/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0940 - acc: 0.6002
# Epoch 466/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0949 - acc: 0.5993
# Epoch 467/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.0942 - acc: 0.5996
# Epoch 468/1000
# 51/51 [==============================] - 3s 57ms/step - loss: 0.0932 - acc: 0.5998
# Epoch 469/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0905 - acc: 0.6003
# Epoch 470/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0908 - acc: 0.6004
# Epoch 471/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.0897 - acc: 0.6000
# Epoch 472/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.0892 - acc: 0.6002
# Epoch 473/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0890 - acc: 0.6005
# Epoch 474/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0887 - acc: 0.6008
# Epoch 475/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0895 - acc: 0.6004
# Epoch 476/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0883 - acc: 0.6002
# Epoch 477/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0884 - acc: 0.6001
# Epoch 478/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0858 - acc: 0.6007
# Epoch 479/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0889 - acc: 0.6003
# Epoch 480/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0830 - acc: 0.6012
# Epoch 481/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0855 - acc: 0.6003
# Epoch 482/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.0864 - acc: 0.6001
# Epoch 483/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.0814 - acc: 0.6013
# Epoch 484/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.0802 - acc: 0.6018
# Epoch 485/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.0810 - acc: 0.6016
# Epoch 486/1000
# 51/51 [==============================] - 3s 58ms/step - loss: 0.0823 - acc: 0.6012
# Epoch 487/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.0812 - acc: 0.6011
# Epoch 488/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.0825 - acc: 0.6010
# Epoch 489/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.0785 - acc: 0.6015
# Epoch 490/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.0804 - acc: 0.6013
# Epoch 491/1000
# ...
# Epoch 838/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0139 - acc: 0.6071
# Epoch 839/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0137 - acc: 0.6072
# Epoch 840/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0136 - acc: 0.6071
# Epoch 841/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0116 - acc: 0.6075
# Epoch 842/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0136 - acc: 0.6070
# Epoch 843/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0135 - acc: 0.6071
# Epoch 844/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0145 - acc: 0.6068
# Epoch 845/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0133 - acc: 0.6071
# Epoch 846/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0138 - acc: 0.6071
# Epoch 847/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0171 - acc: 0.6061
# Epoch 848/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0128 - acc: 0.6073
# Epoch 849/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0125 - acc: 0.6071
# Epoch 850/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0151 - acc: 0.6069
# Epoch 851/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0143 - acc: 0.6067
# Epoch 852/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0138 - acc: 0.6071
# Epoch 853/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0144 - acc: 0.6066
# Epoch 854/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0120 - acc: 0.6072
# Epoch 855/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0108 - acc: 0.6076
# Epoch 856/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0129 - acc: 0.6072
# Epoch 857/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0128 - acc: 0.6072
# Epoch 858/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0166 - acc: 0.6064
# Epoch 859/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.0135 - acc: 0.6069
# Epoch 860/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0111 - acc: 0.6074
# Epoch 861/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0142 - acc: 0.6068
# Epoch 862/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0125 - acc: 0.6072
# Epoch 863/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0128 - acc: 0.6069
# Epoch 864/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0139 - acc: 0.6069
# Epoch 865/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0131 - acc: 0.6070
# Epoch 866/1000
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0133 - acc: 0.6070
# Epoch 867/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0103 - acc: 0.6075
# Epoch 868/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0133 - acc: 0.6068
# Epoch 869/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0119 - acc: 0.6072
# Epoch 870/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0142 - acc: 0.6068
# Epoch 871/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0120 - acc: 0.6070
# Epoch 872/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0121 - acc: 0.6073
# Epoch 873/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0124 - acc: 0.6071
# Epoch 874/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0111 - acc: 0.6074
# Epoch 875/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0136 - acc: 0.6070
# Epoch 876/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0129 - acc: 0.6069
# Epoch 877/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0114 - acc: 0.6074
# Epoch 878/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0146 - acc: 0.6069
# Epoch 879/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0127 - acc: 0.6069
# Epoch 880/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0119 - acc: 0.6071
# Epoch 881/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0142 - acc: 0.6068
# Epoch 882/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0133 - acc: 0.6070
# Epoch 883/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0112 - acc: 0.6073
# Epoch 884/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0157 - acc: 0.6066
# Epoch 885/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0120 - acc: 0.6071
# Epoch 886/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0124 - acc: 0.6070
# Epoch 887/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0133 - acc: 0.6070
# Epoch 888/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0122 - acc: 0.6072
# Epoch 889/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0107 - acc: 0.6075
# Epoch 890/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0126 - acc: 0.6070
# Epoch 891/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0124 - acc: 0.6071
# Epoch 892/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0115 - acc: 0.6073
# Epoch 893/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0125 - acc: 0.6070
# Epoch 894/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0147 - acc: 0.6066
# Epoch 895/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0145 - acc: 0.6067
# Epoch 896/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0117 - acc: 0.6070
# Epoch 897/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0123 - acc: 0.6070
# Epoch 898/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.0113 - acc: 0.6072
# Epoch 899/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0129 - acc: 0.6068
# Epoch 900/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0110 - acc: 0.6072
# Epoch 901/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0121 - acc: 0.6069
# Epoch 902/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0112 - acc: 0.6071
# Epoch 903/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0127 - acc: 0.6070
# Epoch 904/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0110 - acc: 0.6072
# Epoch 905/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0126 - acc: 0.6069
# Epoch 906/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0162 - acc: 0.6061
# Epoch 907/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0145 - acc: 0.6066
# Epoch 908/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0093 - acc: 0.6077
# Epoch 909/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0160 - acc: 0.6060
# Epoch 910/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0125 - acc: 0.6070
# Epoch 911/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0131 - acc: 0.6071
# Epoch 912/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0128 - acc: 0.6069
# Epoch 913/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0121 - acc: 0.6071
# Epoch 914/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0094 - acc: 0.6077
# Epoch 915/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0121 - acc: 0.6071
# Epoch 916/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0112 - acc: 0.6072
# Epoch 917/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0124 - acc: 0.6071
# Epoch 918/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0132 - acc: 0.6067
# Epoch 919/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0129 - acc: 0.6064
# Epoch 920/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0096 - acc: 0.6076
# Epoch 921/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0146 - acc: 0.6067
# Epoch 922/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0115 - acc: 0.6071
# Epoch 923/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0122 - acc: 0.6071
# Epoch 924/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.0109 - acc: 0.6072
# Epoch 925/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0125 - acc: 0.6070
# Epoch 926/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0121 - acc: 0.6070
# Epoch 927/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0132 - acc: 0.6069
# Epoch 928/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0108 - acc: 0.6070
# Epoch 929/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0109 - acc: 0.6073
# Epoch 930/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0109 - acc: 0.6071
# Epoch 931/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0131 - acc: 0.6069
# Epoch 932/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.0116 - acc: 0.6072
# Epoch 933/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0100 - acc: 0.6074
# Epoch 934/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0096 - acc: 0.6074
# Epoch 935/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0133 - acc: 0.6068
# Epoch 936/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0112 - acc: 0.6072
# Epoch 937/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0123 - acc: 0.6070
# Epoch 938/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0139 - acc: 0.6066
# Epoch 939/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0113 - acc: 0.6073
# Epoch 940/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0108 - acc: 0.6072
# Epoch 941/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0133 - acc: 0.6069
# Epoch 942/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0098 - acc: 0.6074
# Epoch 943/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0127 - acc: 0.6068
# Epoch 944/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0093 - acc: 0.6077
# Epoch 945/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0111 - acc: 0.6072
# Epoch 946/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0150 - acc: 0.6065
# Epoch 947/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0129 - acc: 0.6068
# Epoch 948/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0126 - acc: 0.6067
# Epoch 949/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0105 - acc: 0.6070
# Epoch 950/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0132 - acc: 0.6065
# Epoch 951/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0101 - acc: 0.6074
# Epoch 952/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0111 - acc: 0.6072
# Epoch 953/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0127 - acc: 0.6066
# Epoch 954/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0104 - acc: 0.6071
# Epoch 955/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0109 - acc: 0.6073
# Epoch 956/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0104 - acc: 0.6072
# Epoch 957/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0111 - acc: 0.6070
# Epoch 958/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0108 - acc: 0.6070
# Epoch 959/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0108 - acc: 0.6071
# Epoch 960/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0125 - acc: 0.6067
# Epoch 961/1000
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0103 - acc: 0.6073
# Epoch 962/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0103 - acc: 0.6072
# Epoch 963/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0089 - acc: 0.6077
# Epoch 964/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0144 - acc: 0.6063
# Epoch 965/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.0088 - acc: 0.6076
# Epoch 966/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0112 - acc: 0.6069
# Epoch 967/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0131 - acc: 0.6066
# Epoch 968/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0130 - acc: 0.6066
# Epoch 969/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0091 - acc: 0.6074
# Epoch 970/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0121 - acc: 0.6069
# Epoch 971/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0124 - acc: 0.6069
# Epoch 972/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0095 - acc: 0.6074
# Epoch 973/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0132 - acc: 0.6068
# Epoch 974/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0127 - acc: 0.6068
# Epoch 975/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0103 - acc: 0.6072
# Epoch 976/1000
# 51/51 [==============================] - 4s 69ms/step - loss: 0.0111 - acc: 0.6070
# Epoch 977/1000
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0098 - acc: 0.6071
# Epoch 978/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0100 - acc: 0.6071
# Epoch 979/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0090 - acc: 0.6074
# Epoch 980/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0114 - acc: 0.6069
# Epoch 981/1000
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0105 - acc: 0.6071
# Epoch 982/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0108 - acc: 0.6072
# Epoch 983/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0119 - acc: 0.6069
# Epoch 984/1000
# 51/51 [==============================] - 3s 63ms/step - loss: 0.0131 - acc: 0.6066
# Epoch 985/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0111 - acc: 0.6072
# Epoch 986/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0099 - acc: 0.6073
# Epoch 987/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0102 - acc: 0.6072
# Epoch 988/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.0123 - acc: 0.6068
# Epoch 989/1000
# 51/51 [==============================] - 3s 60ms/step - loss: 0.0100 - acc: 0.6074
# Epoch 990/1000
# 51/51 [==============================] - 3s 64ms/step - loss: 0.0092 - acc: 0.6075
# Epoch 991/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0104 - acc: 0.6073
# Epoch 992/1000
# 51/51 [==============================] - 3s 59ms/step - loss: 0.0136 - acc: 0.6065
# Epoch 993/1000
# 51/51 [==============================] - 3s 61ms/step - loss: 0.0102 - acc: 0.6073
# Epoch 994/1000
# 51/51 [==============================] - 3s 62ms/step - loss: 0.0127 - acc: 0.6066
# Epoch 995/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0121 - acc: 0.6069
# Epoch 996/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0088 - acc: 0.6076
# Epoch 997/1000
# 51/51 [==============================] - 3s 68ms/step - loss: 0.0095 - acc: 0.6075
# Epoch 998/1000
# 51/51 [==============================] - 3s 67ms/step - loss: 0.0110 - acc: 0.6071
# Epoch 999/1000
# 51/51 [==============================] - 3s 66ms/step - loss: 0.0093 - acc: 0.6074
# Epoch 1000/1000
# 51/51 [==============================] - 3s 65ms/step - loss: 0.0109 - acc: 0.6070

# %%
model_json = model.to_json()
with open("output/PoemGen_2.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("output/PoemGen_model_weight_2.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
plt.figure(figsize=(10, 6))
plt.grid(True)
plt.plot(history.history['loss'], label='Loss') 
plt.plot(history.history['acc'], label='Acc') 
plt.legend() 
plt.show()
plt.savefig('output/acc_loss_2.png')

# %% [markdown]
# ### Inference

# %%
from tensorflow.keras.models import model_from_json
# loading the model architecture and asigning the weights
json_file = open('output/PoemGen_2.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model_loaded = model_from_json(loaded_model_json, custom_objects={'AttentionLayer': AttentionLayer})
# load weights into new model
model_loaded.load_weights("output/PoemGen_model_weight_2.h5")

# %%
# encoder inference
encoder_inputs = model_loaded.input[0]  #loading encoder_inputs
encoder_outputs, state_h, state_c = model_loaded.layers[6].output #loading encoder_outputs
# print(encoder_inputs.shape)
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# %%
# decoder inference
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_len_input_seq,latent_dim))

# Get the embeddings of the decoder sequence
decoder_inputs = model_loaded.layers[3].output
#print(decoder_inputs.shape)
dec_emb_layer = model_loaded.layers[5]
dec_emb2= dec_emb_layer(decoder_inputs)
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_lstm = model_loaded.layers[7]
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
#attention inference
attn_layer = model_loaded.layers[8]
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
concate = model_loaded.layers[9]
decoder_inf_concat = concate([decoder_outputs2, attn_out_inf])

# %%
# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_dense = model_loaded.layers[10]
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# %%
# Final decoder model
decoder_model = Model(
[decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
[decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Chose the 'start' word as the first word of the target sequence
    target_seq[0, 0] = target_word2index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        if sampled_token_index == 0:
            break
        else:
            sampled_token = target_index2word[sampled_token_index]
            if(sampled_token !='end'):
                decoded_sentence += ' '+ sampled_token
                
            # Exit condition: either hit max length or find stop word.
            if (sampled_token == 'end' or len(decoded_sentence.split()) >= (max_len_target_seq)):
                stop_condition = True

            # Update the ta`rget sequence (of length 1).
            target_seq = np.zeros((1,1))
            target_seq[0, 0] = sampled_token_index

            # Update internal states
            e_h, e_c = h, c

    return decoded_sentence

# %%
for seq_index in [141, 2001, 3002]:
  input_seq = encoder_input_data[seq_index: seq_index + 1]
  decoded_sentence = decode_sequence(input_seq)
  print('-')
  print('Input sentence:', input_sentences[seq_index: seq_index + 1])
  print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: ['song hồ nửa khép cánh mây']
# Decoded sentence:  tường đông ghé mắt ngày ngày hằng trông
# -
# Input sentence: ['chiều nay hồn có trái sầu vừa rơi']
# Decoded sentence:  không tình cũng nghĩa người ơi
# -
# Input sentence: ['từ trong tiền kiếp luân phiên dòng đời']
# Decoded sentence:  hôm nay em trả nợ người

# %%
def make_a_poem_sentence(input_txt):
  input_seq = []
  for t, word in enumerate(input_txt.split()):
    input_seq.append(input_word2index[word])

  input_seq = np.array(input_seq)
  input_seq = pad_sequences([input_seq], maxlen=max_len_input_seq, padding='pre')
  decoded_txt = decode_sequence(input_seq)
  print('Generated poem sentence:', decoded_txt)

# %%
input_txt = 'chào cô em gái hái hoa'
make_a_poem_sentence(input_txt)
# Out:
# Generated poem sentence:  thươngthật lênh lênh màu ngàn qua yêu thương
